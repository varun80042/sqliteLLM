# %%
import pandas as pd
import re

# %%
def get_unique_values(df):
    print(df.nunique())
    print("\n")
    unique_values = {}
    for column in df.columns:
        unique_values[column] = df[column].unique().tolist()
    for column, values in unique_values.items():
        print(f"Unique values in '{column}':")
        print(values)
        print("\n")

def get_NA_values(df):
    missing = df.isnull().sum()
    print(missing)

def get_empty_values(df):
    empty = (df == "").sum()
    print(empty)

def convert_to_short_form(party_name):
    short_form = ''.join(word[0].upper() for word in party_name.split())
    return short_form

# %% [markdown]
# # details_of_assembly_segment_2019.csv

# %%
df = pd.read_csv("details_of_assembly_segment_2019.csv")
df.head()
# Out:
#        state_name parlimentary_constituency_name assembly_constituency_name  \
# 0  Andhra Pradesh                         Aruku              Palakonda (ST)
# 1  Andhra Pradesh                         Aruku              Palakonda (ST)
# 2  Andhra Pradesh                         Aruku              Palakonda (ST)
# 3  Andhra Pradesh                         Aruku              Palakonda (ST)
# 4  Andhra Pradesh                         Aruku              Palakonda (ST)
#
#    nota_votes                                     candidate_name party_name  \
# 0        3736                                KISHORE CHANDRA DEO        TDP
# 1        3736  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...        BJP
# 2        3736                                   GODDETI. MADHAVI      YSRCP
# 3        3736                             SHRUTI DEVI VYRICHERLA        INC
# 4        3736                                GANGULAIAH VAMPURU.        JnP
#
#    votes_secured
# 0        54056.0
# 1         1753.0
# 2        69588.0
# 3         1327.0
# 4         2987.0

# %%
df.rename(columns={'parlimentary_constituency_name':'constituency_name', 
                   'votes_secured':'secured_votes'}, 
                   inplace=True)

# %%
# remove SC and ST
df['constituency_name'] = df['constituency_name'].str.replace(r'\s*\(SC\)\s*|\s*\(ST\)\s*|\s*-\s*\d+$', '', regex=True).str.strip()

# %%
# remove SC and ST
df['assembly_constituency_name'] = df['assembly_constituency_name'].str.replace(r'\s*\(SC\)\s*|\s*\(ST\)\s*|\s*-\s*\d+$', '', regex=True).str.strip()

# %%
# convert party names to short form and upper
df['party_name'] = df['party_name'].str.upper()

# %%
get_NA_values(df)
# Out:
# state_name                     0
# constituency_name              0
# assembly_constituency_name     0
# nota_votes                     0
# candidate_name                 0
# party_name                     0
# secured_votes                 15
# dtype: int64

# %%
df = df.fillna(0)

# %%
get_empty_values(df)
# Out:
# state_name                    0
# constituency_name             0
# assembly_constituency_name    0
# nota_votes                    0
# candidate_name                0
# party_name                    0
# secured_votes                 0
# dtype: int64

# %%
get_unique_values(df)

# %%
df.head()
# Out:
#        state_name constituency_name assembly_constituency_name  nota_votes  \
# 0  Andhra Pradesh             Aruku                  Palakonda        3736
# 1  Andhra Pradesh             Aruku                  Palakonda        3736
# 2  Andhra Pradesh             Aruku                  Palakonda        3736
# 3  Andhra Pradesh             Aruku                  Palakonda        3736
# 4  Andhra Pradesh             Aruku                  Palakonda        3736
#
#                                       candidate_name party_name  secured_votes
# 0                                KISHORE CHANDRA DEO        TDP        54056.0
# 1  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...        BJP         1753.0
# 2                                   GODDETI. MADHAVI      YSRCP        69588.0
# 3                             SHRUTI DEVI VYRICHERLA        INC         1327.0
# 4                                GANGULAIAH VAMPURU.        JNP         2987.0

# %%
df.to_csv('final/final_details_of_assembly_segment_2019.csv')

# %% [markdown]
# # eci_data_2024.csv

# %%
df = pd.read_csv("eci_data_2024.csv", encoding='latin-1')
df.head()
# Out:
#    S.N           Candidate                                Party EVM Votes  \
# 0    1     BISHNU PADA RAY               Bharatiya Janata Party    102182
# 1    2  KULDEEP RAI SHARMA             Indian National Congress     77829
# 2    3          MANOJ PAUL  Andaman Nicobar Democratic Congress      8236
# 3    4          D AYYAPPAN   Communist Party of India (Marxist)      6009
# 4    5     V.K. ABDUL AZIZ                          Independent      2195
#
#   Postal Votes Total Votes % of Votes                      State  \
# 0          254      102436      50.58  Andaman & Nicobar Islands
# 1          211       78040      38.54  Andaman & Nicobar Islands
# 2           18        8254       4.08  Andaman & Nicobar Islands
# 3            8        6017       2.97  Andaman & Nicobar Islands
# 4            8        2203       1.09  Andaman & Nicobar Islands
#
#                     Constituency
# 0  Andaman & Nicobar Islands - 1
# 1  Andaman & Nicobar Islands - 1
# 2  Andaman & Nicobar Islands - 1
# 3  Andaman & Nicobar Islands - 1
# 4  Andaman & Nicobar Islands - 1

# %%
df.rename(columns={'Candidate':'candidate_name', 
                   'Party':'party_name',
                   'Total Votes':'secured_votes',
                   'State':'state_name',
                   'Constituency':'constituency_name'}, 
                   inplace=True)

# %%
# extract constituency number
df['constituency_number'] = df['constituency_name'].str.extract(r'-(\s*\d+)$')[0].str.strip()

# %%
# remove SC and ST
df['constituency_name'] = df['constituency_name'].str.replace(r'\s*\(SC\)\s*|\s*\(ST\)\s*|\s*-\s*\d+$', '', regex=True).str.strip()

# %%
# convert party name to short form and upper case
df['party_name'] = df['party_name'].apply(convert_to_short_form)
df['party_name'] = df['party_name'].str.upper()

# %%
get_NA_values(df)
# Out:
# S.N                    0
# candidate_name         0
# party_name             0
# EVM Votes              0
# Postal Votes           0
# secured_votes          0
# % of Votes             0
# state_name             0
# constituency_name      0
# constituency_number    0
# dtype: int64

# %%
get_empty_values(df)
# Out:
# S.N                    0
# candidate_name         0
# party_name             0
# EVM Votes              0
# Postal Votes           0
# secured_votes          0
# % of Votes             0
# state_name             0
# constituency_name      0
# constituency_number    0
# dtype: int64

# %%
get_unique_values(df)

# %%
df.head()
# Out:
#    S.N      candidate_name party_name EVM Votes Postal Votes secured_votes  \
# 0    1     BISHNU PADA RAY          B    102182          254        102436
# 1    2  KULDEEP RAI SHARMA          I     77829          211         78040
# 2    3          MANOJ PAUL          A      8236           18          8254
# 3    4          D AYYAPPAN          C      6009            8          6017
# 4    5     V.K. ABDUL AZIZ          I      2195            8          2203
#
#   % of Votes                 state_name          constituency_name  \
# 0      50.58  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1      38.54  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2       4.08  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3       2.97  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4       1.09  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#   constituency_number
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
df.to_csv('final/final_eci_data_2024.csv')

# %% [markdown]
# # maha_results_2019.csv

# %%
df = pd.read_csv("maha_results_2019.csv", encoding='latin-1')
df.head()
# Out:
#   ï»¿ STATE/UT NAME   AC NO.     AC NAME                   CANDIDATE NAME   \
# 0        Maharashtra        1  Akkalkuwa               1 ADV. K. C. PADAVI
# 1        Maharashtra        1  Akkalkuwa            2 AAMSHYA FULJI PADAVI
# 2        Maharashtra        1  Akkalkuwa         3 NAGESH DILVARSING PADVI
# 3        Maharashtra        1  Akkalkuwa                            4 NOTA
# 4        Maharashtra        1  Akkalkuwa   5 ADV. KAILAS PRATAPSING VASAVE
#
#    SEX    AGE   CATEGORY   PARTY         SYMBOL    GENERAL    POSTAL   \
# 0  MALE   61.0         ST     INC           Hand      82509     261.0
# 1  MALE   51.0         ST     SHS  Bow and Arrow      80532     142.0
# 2  MALE   44.0         ST     IND      Gas Stove      21583      81.0
# 3   NaN    NaN        NaN    NOTA           NOTA       4856       1.0
# 4  MALE   28.0         ST    AAAP          Broom       4034      21.0
#
#     TOTAL    % VOTES POLLED    TOTAL ELECTORS
# 0    82770         41.255458          278888.0
# 1    80674         40.210738          278888.0
# 2    21664         10.798094          278888.0
# 3     4857          2.420898          278888.0
# 4     4055          2.021154          278888.0

# %%
df.rename(columns={'ï»¿ STATE/UT NAME ':'state_name', 
                   ' AC NO. ':'assembly_constituency_number',
                   ' AC NAME ':'assembly_ constituency_name',
                   ' CANDIDATE NAME ':'candidate_name',
                   ' PARTY ':'party_name',
                   ' TOTAL ELECTORS ':'total_votes_in_state'}, 
                   inplace=True)

# %%
# remove number in candidate name
df['candidate_name'] = df['candidate_name'].str.replace(r'^\d+\s+', '', regex=True)

# %%
get_NA_values(df)
# Out:
# state_name                      0
# assembly_constituency_number    0
# assembly_ constituency_name     0
# candidate_name                  0
#  SEX                            0
#  AGE                            0
#  CATEGORY                       0
# party_name                      0
#  SYMBOL                         0
#  GENERAL                        0
#  POSTAL                         0
#  TOTAL                          0
#  % VOTES POLLED                 0
# total_votes_in_state            0
# dtype: int64

# %%
df.fillna('', inplace=True)

# %%
get_empty_values(df)
# Out:
# state_name                         0
# assembly_constituency_number       0
# assembly_ constituency_name      288
# candidate_name                   288
#  SEX                             576
#  AGE                             576
#  CATEGORY                        576
# party_name                       288
#  SYMBOL                          288
#  GENERAL                           0
#  POSTAL                         1041
#  TOTAL                             0
#  % VOTES POLLED                    0
# total_votes_in_state             288
# dtype: int64

# %%
get_unique_values(df)

# %%
df.head()
# Out:
#     state_name assembly_constituency_number assembly_ constituency_name  \
# 0  Maharashtra                            1                  Akkalkuwa
# 1  Maharashtra                            1                  Akkalkuwa
# 2  Maharashtra                            1                  Akkalkuwa
# 3  Maharashtra                            1                  Akkalkuwa
# 4  Maharashtra                            1                  Akkalkuwa
#
#                   candidate_name  SEX   AGE   CATEGORY  party_name  \
# 0              ADV. K. C. PADAVI  MALE  61.0         ST        INC
# 1           AAMSHYA FULJI PADAVI  MALE  51.0         ST        SHS
# 2        NAGESH DILVARSING PADVI  MALE  44.0         ST        IND
# 3                           NOTA                              NOTA
# 4  ADV. KAILAS PRATAPSING VASAVE  MALE  28.0         ST       AAAP
#
#          SYMBOL    GENERAL   POSTAL    TOTAL    % VOTES POLLED   \
# 0           Hand      82509    261.0    82770         41.255458
# 1  Bow and Arrow      80532    142.0    80674         40.210738
# 2      Gas Stove      21583     81.0    21664         10.798094
# 3           NOTA       4856      1.0     4857          2.420898
# 4          Broom       4034     21.0     4055          2.021154
#
#   total_votes_in_state
# 0             278888.0
# 1             278888.0
# 2             278888.0
# 3             278888.0
# 4             278888.0

# %%
df.to_csv('final/maha_results_2019.csv')

# %% [markdown]
# # Final CSV files

# %%
df = pd.read_csv('final/final_details_of_assembly_segment_2019.csv')
df.head()
# Out:
#    Unnamed: 0      state_name constituency_name assembly_constituency_name  \
# 0           0  Andhra Pradesh             Aruku                  Palakonda
# 1           1  Andhra Pradesh             Aruku                  Palakonda
# 2           2  Andhra Pradesh             Aruku                  Palakonda
# 3           3  Andhra Pradesh             Aruku                  Palakonda
# 4           4  Andhra Pradesh             Aruku                  Palakonda
#
#    nota_votes                                     candidate_name party_name  \
# 0        3736                                KISHORE CHANDRA DEO        TDP
# 1        3736  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...        BJP
# 2        3736                                   GODDETI. MADHAVI      YSRCP
# 3        3736                             SHRUTI DEVI VYRICHERLA        INC
# 4        3736                                GANGULAIAH VAMPURU.        JNP
#
#    secured_votes
# 0        54056.0
# 1         1753.0
# 2        69588.0
# 3         1327.0
# 4         2987.0

# %%
df = pd.read_csv('final/final_eci_data_2024.csv')
df.head()
# Out:
#    Unnamed: 0  S.N      candidate_name party_name EVM Votes Postal Votes  \
# 0           0    1     BISHNU PADA RAY          B    102182          254
# 1           1    2  KULDEEP RAI SHARMA          I     77829          211
# 2           2    3          MANOJ PAUL          A      8236           18
# 3           3    4          D AYYAPPAN          C      6009            8
# 4           4    5     V.K. ABDUL AZIZ          I      2195            8
#
#   secured_votes % of Votes                 state_name  \
# 0        102436      50.58  Andaman & Nicobar Islands
# 1         78040      38.54  Andaman & Nicobar Islands
# 2          8254       4.08  Andaman & Nicobar Islands
# 3          6017       2.97  Andaman & Nicobar Islands
# 4          2203       1.09  Andaman & Nicobar Islands
#
#            constituency_name  constituency_number
# 0  Andaman & Nicobar Islands                    1
# 1  Andaman & Nicobar Islands                    1
# 2  Andaman & Nicobar Islands                    1
# 3  Andaman & Nicobar Islands                    1
# 4  Andaman & Nicobar Islands                    1

# %%
df = pd.read_csv('final/maha_results_2019.csv')
df.head()
# Out:
#    Unnamed: 0   state_name assembly_constituency_number  \
# 0           0  Maharashtra                            1
# 1           1  Maharashtra                            1
# 2           2  Maharashtra                            1
# 3           3  Maharashtra                            1
# 4           4  Maharashtra                            1
#
#   assembly_ constituency_name                 candidate_name  SEX    AGE   \
# 0                  Akkalkuwa               ADV. K. C. PADAVI  MALE   61.0
# 1                  Akkalkuwa            AAMSHYA FULJI PADAVI  MALE   51.0
# 2                  Akkalkuwa         NAGESH DILVARSING PADVI  MALE   44.0
# 3                  Akkalkuwa                            NOTA   NaN    NaN
# 4                  Akkalkuwa   ADV. KAILAS PRATAPSING VASAVE  MALE   28.0
#
#    CATEGORY  party_name        SYMBOL    GENERAL    POSTAL    TOTAL   \
# 0         ST        INC           Hand      82509     261.0    82770
# 1         ST        SHS  Bow and Arrow      80532     142.0    80674
# 2         ST        IND      Gas Stove      21583      81.0    21664
# 3        NaN       NOTA           NOTA       4856       1.0     4857
# 4         ST       AAAP          Broom       4034      21.0     4055
#
#     % VOTES POLLED   total_votes_in_state
# 0         41.255458              278888.0
# 1         40.210738              278888.0
# 2         10.798094              278888.0
# 3          2.420898              278888.0
# 4          2.021154              278888.0
